# %% [markdown]
# # Exploratory Data Analysis (EDA) project proposal
# ### _Abdulaziz Alshehri_

# %% [markdown]
# **Organization:**
# I'm looking for a job in Taxi & Limousine Commission (TLC) in New York City (NYC) as a data scientist.
#
# **Description:**
# For that, I'm planning to catch their attention by presenting an exploratory analysis that can show the different patterns/behavior people follow in the daily transportations based on data of subway turnstile and taxis in NYC.
#
# **Benefits:**
# This can be helpful in understanding people's movement patterns/behavior in the city which will support decision-making for stakeholders (e.g. TLC).

# %% [markdown]
# ![map-example.png](attachment:map-example.png) <center>Map Example of the visual output!</center>

# %% [markdown]
# **Needed Data:**
# To achieve this we need
# **1-** Metropolitan Transportation Authority (MTA) dataset [Link](http://web.mta.info/developers/turnstile.html) which provides the basic data about each turnstile (e.g. turnstile id, data observation date and time, etc) in addition to their quantitive entries and exits data.
# **2-** NYC Taxi datasert [Link](https://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.pa) which provide additinal data about poeple transportation patterns.
# **3-** NYC Turnstiles Station List dataset [Link](https://qri.cloud/nyc-transit-data/turnstiles_station_list) which provides the needed spatial data to combine with the NYC taxi dataset.
