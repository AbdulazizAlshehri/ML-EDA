# %% [markdown]
# # Database Credentials (read only user)

# %% [markdown]
# host="34.132.168.244"
#
# database="EDAdb"
#
# user="mrdmitry2"
#
# password="Bonus"

# %% [markdown]
# # SQL

# %% [markdown]
# -- Creating User
#
# CREATE USER mrdmitry2 WITH PASSWORD 'Bonus';
#
#
# -- Granting Reading Privileges
#
# GRANT CONNECT ON DATABASE "EDAdb" TO mrdmitry2;
#
# GRANT SELECT ON ALL TABLES IN SCHEMA public TO mrdmitry2;
#
#
# -- Revoking Udate, Delete, Alter Privileges
#
# REVOKE CREATE ON SCHEMA public FROM mrdmitry2;
#
#
# -- Check User Permissions
#
# SELECT * FROM information_schema.role_table_grants WHERE grantee='mrdmitry2';

# %% [markdown]
# # OUTPUT - USER Permissions

# %% [markdown]
# ![ReadOnlyUser%20Premissions.png](attachment:ReadOnlyUser%20Premissions.png)
